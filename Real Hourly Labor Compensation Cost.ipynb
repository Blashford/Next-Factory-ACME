# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress
import scipy.stats as st
from pprint import pprint

# %%
# Read in csv file
df = pd.read_csv('state_data.csv')
df.columns
# Out:
# Index(['State', 'Sector', 'Year', 'Employment (2012=100)',
#        'Employment (percent change)', 'Hourly labor compensation (2012=100)',
#        'Hourly labor compensation (percent change)',
#        'Hourly labor compensation cost ($/hour)',
#        'Hourly labor compensation cost (percent change)', 'Hours (2012=100)',
#        'Hours (percent change)', 'Implicit output deflator (2012=100)',
#        'Implicit output deflator (percent change)',
#        'Labor compensation (2012=100)', 'Labor compensation (percent change)',
#        'Labor compensation cost (million $)',
#        'Labor compensation cost (percent change)',
#        'Labor productivity (2012=100)', 'Labor productivity (percent change)',
#        'Number of employees (percent change)',
#        'Number of employees (thousands)', 'Number of hours (millions)',
#        'Number of hours (percent change)', 'Output (2012=100)',
#        'Output (percent change)', 'Output per employee (2012=100)',
# ...

# %%
# Review Dataframe 
df.head()
# Out:
#      State           Sector  Year  Employment (2012=100)  \
# 0  Alabama  Private Nonfarm  2007                109.312
# 1  Alabama  Private Nonfarm  2008                105.771
# 2  Alabama  Private Nonfarm  2009                 99.487
# 3  Alabama  Private Nonfarm  2010                 99.046
# 4  Alabama  Private Nonfarm  2011                 98.814
#
#    Employment (percent change)  Hourly labor compensation (2012=100)  \
# 0                          NaN                                88.207
# 1                         -3.2                                92.369
# 2                         -5.9                                97.805
# 3                         -0.4                                99.169
# 4                         -0.2                               101.158
#
#    Hourly labor compensation (percent change)  \
# 0                                         NaN
# 1                                         4.7
# 2                                         5.9
# ...

# %%
# Drop rows with NaN from dataframe
df = df.dropna(how='any')

# %%
df.head()
# Out:
#      State           Sector  Year  Employment (2012=100)  \
# 1  Alabama  Private Nonfarm  2008                105.771
# 2  Alabama  Private Nonfarm  2009                 99.487
# 3  Alabama  Private Nonfarm  2010                 99.046
# 4  Alabama  Private Nonfarm  2011                 98.814
# 5  Alabama  Private Nonfarm  2012                100.000
#
#    Employment (percent change)  Hourly labor compensation (2012=100)  \
# 1                         -3.2                                92.369
# 2                         -5.9                                97.805
# 3                         -0.4                                99.169
# 4                         -0.2                               101.158
# 5                          1.2                               100.000
#
#    Hourly labor compensation (percent change)  \
# 1                                         4.7
# 2                                         5.9
# 3                                         1.4
# ...

# %%
# Create varialbles for plotting from dataframe
labor_prod = df["Labor productivity (percent change)"]
prod_value_prct = df["Value of production (percent change)"]
employ_prct=df["Employment (percent change)"]
hourly_labor=df["Hourly labor compensation (percent change)"]
hour_labor_comp=df["Hourly labor compensation cost (percent change)"]
hourly_compcost=df["Real hourly labor compensation cost (percent change)"]
labor_comp_real=df["Real labor compensation (percent change)"]
labor_compcost=df["Real labor compensation cost (percent change)"]
unit_laborcost=df["Unit labor cost (percent change)"]

labor_comp=df["Labor compensation (percent change)"]
labor_cost=df["Labor compensation cost (percent change)"]
num_employ=df["Number of employees (percent change)"]
num_hours=df["Number of hours (percent change)"]
output=df["Output (percent change)"]
output_employ=df["Output per employee (percent change)"]
real_hour_comp=df["Real hourly labor compensation (percent change)"]

# %%
# Scatter plot for "Real hourly labor compensation cost (percent change)" vs value of production
# Calculating correlation coefficient and regression line
plt.scatter(hourly_compcost, prod_value_prct, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, prod_value_prct)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, prod_value_prct)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(6,15),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost vs Value of Production (2007 - 2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel('Value of Production (million$) % Change')

plt.show()
# Out:
# The correlation between both factors is 0.01

# %%
# Scatter plot for "Real hourly labor compensation cost (percent change)" vs employment
# Calculating correlation coefficient and regression line
plt.scatter(hourly_compcost, employ_prct, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, employ_prct)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, employ_prct)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(5.5,7),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost vs Employment (2007 - 2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel('Employment (2012=100) % Change')

plt.show()
# Out:
# The correlation between both factors is -0.06

# %%
# Scatter plot for "Real hourly labor compensation cost (percent change)" vs hourly labor compensation
# Calculating correlation coefficient and regression line
plt.scatter(hourly_compcost, hourly_labor, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, hourly_labor)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, hourly_labor)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost (percent change) vs Hourly Labor Compensation (2007 -2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel('Hourly Labor Compensation (2012=100) % Change')

plt.show()
# Out:
# The correlation between both factors is 0.72

# %%
# Scatter plot for "Real hourly labor compensation cost (percent change)" vs hourly labor compensation
# Calculating correlation coefficient and regression line
plt.scatter(hourly_compcost, hour_labor_comp, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, hour_labor_comp)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, hour_labor_comp)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost (percent change) vs Hourly Labor Compensation Cost (2007 - 2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel('Hourly Labor Compensation Cost ($/hr) % Change')

plt.show()
# Out:
# The correlation between both factors is 0.72

# %%
# Scatter plot for labor productivity vs real hourly labor compensation cost
# Calculating correlation coefficient and regression line
plt.scatter(labor_prod, hourly_compcost, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, hourly_compcost)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, hourly_compcost)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(6,7),fontsize=15,color="red")


plt.title('Labor Productivity vs Real Hourly Labor Compensation Cost (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel('Real Hourly Labor Compensation Cost ($/hr) % Change')


plt.show()
# Out:
# The correlation between both factors is 0.39

# %%
# Scatter plot for "Real hourly labor compensation cost (percent change)" vs real labor compensation
# Calculating correlation coefficient and regression line
plt.scatter(hourly_compcost, labor_comp_real, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, labor_comp_real)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, labor_comp_real)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost (percent change) vs Real Labor Compensation (2007 - 2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel("Real Labor Compensation (2012=100) % Change")


plt.show()
# Out:
# The correlation between both factors is 0.33

# %%
# Scatter plot for "Real hourly labor compensation cost (percent change)" vs real labor compensation cost
# Calculating correlation coefficient and regression line

plt.scatter(hourly_compcost, labor_compcost, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, labor_compcost)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, labor_compcost)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost (percent change) vs Real Labor Compensation Cost (2007 - 2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel("Real Labor Compensation Cost ($/hr) % Change")


plt.show()
# Out:
# The correlation between both factors is 0.33

# %%
# Scatter plot for Real hourly labor compensation cost (percent change) vs unit labor cost
# Calculating correlation coefficient and regression line

plt.scatter(hourly_compcost, unit_laborcost, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, unit_laborcost)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, unit_laborcost)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(6,7),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost (percent change) vs Unit Labor Cost (2007 - 2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel("Unit Labor Cost (2012=100) % Change")


plt.show()
# Out:
# The correlation between both factors is 0.07

# %%
# Scatter plot for "Real hourly labor compensation cost (percent change)" vs labor compensation
# Calculating correlation coefficient and regression line

plt.scatter(hourly_compcost, labor_comp, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, labor_comp)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, labor_comp)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(5,13),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost (percent change) vs Labor Compensation (2007 - 2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel("Labor Compensation (2012=100) % Change")


plt.show()
# Out:
# The correlation between both factors is 0.12

# %%
# Scatter plot for "Real hourly labor compensation cost (percent change)" vs labor compensation cost
# Calculating correlation coefficient and regression line

plt.scatter(hourly_compcost, labor_cost, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, labor_cost)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, labor_cost)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(5,14),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost (percent change) vs Labor Compensation Cost (2007 - 2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel("Labor Compensation Cost (million$) % Change")



plt.show()
# Out:
# The correlation between both factors is 0.12

# %%
# Scatter plot for "Real hourly labor compensation cost (percent change)" vs number of employees
# Calculating correlation coefficient and regression line

plt.scatter(hourly_compcost, num_employ, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, num_employ)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, num_employ)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(5,6),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost (percent change) vs Number of Employees (2007 - 2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel("Number of Employees (thousands) % Change")


plt.show()
# Out:
# The correlation between both factors is -0.06

# %%
# Scatter plot for "Real hourly labor compensation cost (percent change)" vs number of hours
# Calculating correlation coefficient and regression line

plt.scatter(hourly_compcost, num_hours, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, num_hours)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, num_hours)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(5.5,8),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost (percent change) vs Number of Hours (2007 - 2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel("Number of Hours (millions) % Change")


plt.show()
# Out:
# The correlation between both factors is -0.23

# %%
# Scatter plot for "Real hourly labor compensation cost (percent change)" vs output
# Calculating correlation coefficient and regression line

plt.scatter(hourly_compcost, output, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, output)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, output)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(6,15),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost (percent change) vs Output (2007 - 2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel("Output (2012=100) % Change")


plt.show()
# Out:
# The correlation between both factors is 0.08

# %%
# Scatter plot for "Real hourly labor compensation cost (percent change)" vs output per employee
# Calculating correlation coefficient and regression line

plt.scatter(hourly_compcost, output_employ, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, output_employ)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, output_employ)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(-2.5,10),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost (percent change) vs Output per Employee (2007 - 2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel("Output per Employee (2012=100) % Change")


plt.show()
# Out:
# The correlation between both factors is 0.16

# %%
# Scatter plot for "Real hourly labor compensation cost (percent change)" vs real hourly labor compensation
# Calculating correlation coefficient and regression line

plt.scatter(hourly_compcost,real_hour_comp, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(hourly_compcost, real_hour_comp)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(hourly_compcost, real_hour_comp)
regress_values = hourly_compcost * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(hourly_compcost,regress_values,"r-")
plt.annotate(line_eq,(6,7),fontsize=15,color="red")

plt.title('Real hourly labor compensation cost (percent change) vs Real Hourly Labor Compensation (2007 - 2019)')
plt.xlabel('Real hourly labor compensation cost (percent change)')
plt.ylabel("Real Hourly Labor Compensation (20120=100) % Change")


plt.show()
# Out:
# The correlation between both factors is 1.0
