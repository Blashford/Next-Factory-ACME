# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress
import scipy.stats as st
from pprint import pprint

# %%
# Read in csv file
df = pd.read_csv('state_data.csv')
df.columns
# Out:
# Index(['State', 'Sector', 'Year', 'Employment (2012=100)',
#        'Employment (percent change)', 'Hourly labor compensation (2012=100)',
#        'Hourly labor compensation (percent change)',
#        'Hourly labor compensation cost ($/hour)',
#        'Hourly labor compensation cost (percent change)', 'Hours (2012=100)',
#        'Hours (percent change)', 'Implicit output deflator (2012=100)',
#        'Implicit output deflator (percent change)',
#        'Labor compensation (2012=100)', 'Labor compensation (percent change)',
#        'Labor compensation cost (million $)',
#        'Labor compensation cost (percent change)',
#        'Labor productivity (2012=100)', 'Labor productivity (percent change)',
#        'Number of employees (percent change)',
#        'Number of employees (thousands)', 'Number of hours (millions)',
#        'Number of hours (percent change)', 'Output (2012=100)',
#        'Output (percent change)', 'Output per employee (2012=100)',
# ...

# %%
# Review Dataframe 
df.head()
# Out:
#      State           Sector  Year  Employment (2012=100)  \
# 0  Alabama  Private Nonfarm  2007                109.312
# 1  Alabama  Private Nonfarm  2008                105.771
# 2  Alabama  Private Nonfarm  2009                 99.487
# 3  Alabama  Private Nonfarm  2010                 99.046
# 4  Alabama  Private Nonfarm  2011                 98.814
#
#    Employment (percent change)  Hourly labor compensation (2012=100)  \
# 0                          NaN                                88.207
# 1                         -3.2                                92.369
# 2                         -5.9                                97.805
# 3                         -0.4                                99.169
# 4                         -0.2                               101.158
#
#    Hourly labor compensation (percent change)  \
# 0                                         NaN
# 1                                         4.7
# 2                                         5.9
# ...

# %%
# Drop rows with NaN from dataframe
df = df.dropna(how='any')

# %%
df.head()
# Out:
#      State           Sector  Year  Employment (2012=100)  \
# 1  Alabama  Private Nonfarm  2008                105.771
# 2  Alabama  Private Nonfarm  2009                 99.487
# 3  Alabama  Private Nonfarm  2010                 99.046
# 4  Alabama  Private Nonfarm  2011                 98.814
# 5  Alabama  Private Nonfarm  2012                100.000
#
#    Employment (percent change)  Hourly labor compensation (2012=100)  \
# 1                         -3.2                                92.369
# 2                         -5.9                                97.805
# 3                         -0.4                                99.169
# 4                         -0.2                               101.158
# 5                          1.2                               100.000
#
#    Hourly labor compensation (percent change)  \
# 1                                         4.7
# 2                                         5.9
# 3                                         1.4
# ...

# %%
# Create varialbles for plotting from dataframe
labor_prod = df["Labor productivity (percent change)"]
prod_value_prct = df["Value of production (percent change)"]
employ_prct=df["Employment (percent change)"]
hourly_labor=df["Hourly labor compensation (percent change)"]
hour_labor_comp=df["Hourly labor compensation cost (percent change)"]
hourly_compcost=df["Real hourly labor compensation cost (percent change)"]
labor_comp_real=df["Real labor compensation (percent change)"]
labor_compcost=df["Real labor compensation cost (percent change)"]
unit_laborcost=df["Unit labor cost (percent change)"]

labor_comp=df["Labor compensation (percent change)"]
labor_cost=df["Labor compensation cost (percent change)"]
num_employ=df["Number of employees (percent change)"]
num_hours=df["Number of hours (percent change)"]
output=df["Output (percent change)"]
output_employ=df["Output per employee (percent change)"]
real_hour_comp=df["Real hourly labor compensation (percent change)"]

# %%
# Scatter plot for labor productivity vs value of production
# Calculating correlation coefficient and regression line
plt.scatter(labor_prod, prod_value_prct, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, prod_value_prct)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, prod_value_prct)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(6,15),fontsize=15,color="red")

plt.title('Labor Productivity vs Value of Production (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel('Value of Production (million$) % Change')
plt.savefig("Images/ChangePrct_Production_Value.png")
plt.show()
# Out:
# The correlation between both factors is 0.11

# %%
# Scatter plot for labor productivity vs employment
# Calculating correlation coefficient and regression line
plt.scatter(labor_prod, employ_prct, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, employ_prct)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, employ_prct)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(5.5,7),fontsize=15,color="red")

plt.title('Labor Productivity vs Employment (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel('Employment (2012=100) % Change')
plt.savefig("Images/ChangePrct_Employment.png")
plt.show()
# Out:
# The correlation between both factors is -0.33

# %%
# Scatter plot for labor productivity vs hourly labor compensation
# Calculating correlation coefficient and regression line
plt.scatter(labor_prod, hourly_labor, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, hourly_labor)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, hourly_labor)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title('Labor Productivity vs Hourly Labor Compensation (2007 -2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel('Hourly Labor Compensation (2012=100) % Change')
plt.savefig("Images/ChangePrct_Hourly_Labor_Comp.png")
plt.show()
# Out:
# The correlation between both factors is 0.34

# %%
# Scatter plot for labor productivity vs hourly labor compensation
# Calculating correlation coefficient and regression line
plt.scatter(labor_prod, hour_labor_comp, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, hour_labor_comp)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, hour_labor_comp)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title('Labor Productivity vs Hourly Labor Compensation Cost (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel('Hourly Labor Compensation Cost ($/hr) % Change')
plt.savefig("Images/ChangePrct_Hourly_Labor_Comp_Cost.png")
plt.show()
# Out:
# The correlation between both factors is 0.34

# %%
# Scatter plot for labor productivity vs real hourly labor compensation cost
# Calculating correlation coefficient and regression line
plt.scatter(labor_prod, hourly_compcost, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, hourly_compcost)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, hourly_compcost)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(6,7),fontsize=15,color="red")


plt.title('Labor Productivity vs Real Hourly Labor Compensation Cost (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel('Real Hourly Labor Compensation Cost ($/hr) % Change')
plt.savefig("Images/ChangePrct_Real_Hourly_Labor_Comp_Cost.png")

plt.show()
# Out:
# The correlation between both factors is 0.39

# %%
# Scatter plot for labor productivity vs real labor compensation
# Calculating correlation coefficient and regression line
plt.scatter(labor_prod, labor_comp_real, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, labor_comp_real)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, labor_comp_real)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title('Labor Productivity vs Real Labor Compensation (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel("Real Labor Compensation (2012=100) % Change")
plt.savefig("Images/ChangePrct_Real_Labor_Comp.png")

plt.show()
# Out:
# The correlation between both factors is -0.16

# %%
# Scatter plot for labor productivity vs real labor compensation cost
# Calculating correlation coefficient and regression line

plt.scatter(labor_prod, labor_compcost, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, labor_compcost)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, labor_compcost)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title('Labor Productivity vs Real Labor Compensation Cost (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel("Real Labor Compensation Cost ($/hr) % Change")
plt.savefig("Images/ChangePrct_Real_Labor_Comp_Cost.png")

plt.show()
# Out:
# The correlation between both factors is -0.16

# %%
# Scatter plot for labor productivity vs unit labor cost
# Calculating correlation coefficient and regression line

plt.scatter(labor_prod, unit_laborcost, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, unit_laborcost)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, unit_laborcost)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(6,7),fontsize=15,color="red")

plt.title('Labor Productivity vs Unit Labor Cost (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel("Unit Labor Cost (2012=100) % Change")
plt.savefig("Images/ChangePrct_Unit_Labor_Cost.png")

plt.show()
# Out:
# The correlation between both factors is -0.79

# %%
# Scatter plot for labor productivity vs labor compensation
# Calculating correlation coefficient and regression line

plt.scatter(labor_prod, labor_comp, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, labor_comp)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, labor_comp)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(5,13),fontsize=15,color="red")

plt.title('Labor Productivity vs Labor Compensation (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel("Labor Compensation (2012=100) % Change")
plt.savefig("Images/ChangePrct_Labor_Compensation.png")

plt.show()
# Out:
# The correlation between both factors is -0.19

# %%
# Scatter plot for labor productivity vs labor compensation cost
# Calculating correlation coefficient and regression line

plt.scatter(labor_prod, labor_cost, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, labor_cost)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, labor_cost)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(5,14),fontsize=15,color="red")

plt.title('Labor Productivity vs Labor Compensation Cost (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel("Labor Compensation Cost (million$) % Change")
plt.savefig("Images/ChangePrct_Labor_Compensation_Cost.png")


plt.show()
# Out:
# The correlation between both factors is -0.19

# %%
# Scatter plot for labor productivity vs number of employees
# Calculating correlation coefficient and regression line

plt.scatter(labor_prod, num_employ, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, num_employ)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, num_employ)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(5,6),fontsize=15,color="red")

plt.title('Labor Productivity vs Number of Employees (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel("Number of Employees (thousands) % Change")
plt.savefig("Images/ChangePrct_Labor_Num_Employees.png")

plt.show()
# Out:
# The correlation between both factors is -0.33

# %%
# Scatter plot for labor productivity vs number of hours
# Calculating correlation coefficient and regression line

plt.scatter(labor_prod, num_hours, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, num_hours)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, num_hours)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(5.5,8),fontsize=15,color="red")

plt.title('Labor Productivity vs Number of Hours (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel("Number of Hours (millions) % Change")
plt.savefig("Images/ChangePrct_Labor_Num_Hours.png")

plt.show()
# Out:
# The correlation between both factors is -0.39

# %%
# Scatter plot for labor productivity vs output
# Calculating correlation coefficient and regression line

plt.scatter(labor_prod, output, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, output)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, output)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(6,15),fontsize=15,color="red")

plt.title('Labor Productivity vs Output (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel("Output (2012=100) % Change")
plt.savefig("Images/ChangePrct_Labor_Output.png")

plt.show()
# Out:
# The correlation between both factors is 0.4

# %%
# Scatter plot for labor productivity vs output per employee
# Calculating correlation coefficient and regression line

plt.scatter(labor_prod, output_employ, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, output_employ)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, output_employ)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(-2.5,10),fontsize=15,color="red")

plt.title('Labor Productivity vs Output per Employee (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel("Output per Employee (2012=100) % Change")
plt.savefig("Images/ChangePrct_Labor_Output_Employee.png")

plt.show()
# Out:
# The correlation between both factors is 0.86

# %%
# Scatter plot for labor productivity vs real hourly labor compensation
# Calculating correlation coefficient and regression line

plt.scatter(labor_prod,real_hour_comp, marker = "o", facecolor="blue", edgecolors = "black")
correlation = st.pearsonr(labor_prod, real_hour_comp)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(labor_prod, real_hour_comp)
regress_values = labor_prod * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(labor_prod,regress_values,"r-")
plt.annotate(line_eq,(6,7),fontsize=15,color="red")

plt.title('Labor Productivity vs Real Hourly Labor Compensation (2007 - 2019)')
plt.xlabel('Labor Productivity (2012=100) % Change')
plt.ylabel("Real Hourly Labor Compensation (20120=100) % Change")
plt.savefig("Images/ChangePrct_Real_Hour_Labor_Comp.png")

plt.show()
# Out:
# The correlation between both factors is 0.39
